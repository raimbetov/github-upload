# %%
import numpy as np
import pandas as pd
import seaborn as sns

# %%
import matplotlib.pyplot as plt

# %%
x = np.random.normal(50, 15, 5000)

# %%
x.mean()
# Out:
# 50.04606362846457

# %%
x.std()
# Out:
# 14.910495690548832

# %%
y = np.random.normal(49, 16, 5000)

# %%
sns.jointplot(x = x, y = y, kind="scatter", s=10, color="m", edgecolor = "skyblue", linewidth = 1)
